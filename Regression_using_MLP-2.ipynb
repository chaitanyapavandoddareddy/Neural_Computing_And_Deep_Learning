# %% [markdown]
# # Keras Regression Code Along Project
#
# Let's now apply our knowledge to a more realistic data set. Here we will also focus on feature engineering and cleaning our data!

# %% [markdown]
# ## The Data
#
# We will be using data from a Kaggle data set:
#
# https://www.kaggle.com/harlfoxem/housesalesprediction
#
# #### Feature Columns
#
# * id - Unique ID for each home sold
# * date - Date of the home sale
# * price - Price of each home sold
# * bedrooms - Number of bedrooms
# * bathrooms - Number of bathrooms, where .5 accounts for a room with a toilet but no shower
# * sqft_living - Square footage of the apartments interior living space
# * sqft_lot - Square footage of the land space
# * floors - Number of floors
# * waterfront - A dummy variable for whether the apartment was overlooking the waterfront or not
# * view - An index from 0 to 4 of how good the view of the property was
# * condition - An index from 1 to 5 on the condition of the apartment,
# * grade - An index from 1 to 13, where 1-3 falls short of building construction and design, 7 has an average level of construction and design, and 11-13 have a high quality level of construction and design.
# * sqft_above - The square footage of the interior housing space that is above ground level
# * sqft_basement - The square footage of the interior housing space that is below ground level
# * yr_built - The year the house was initially built
# * yr_renovated - The year of the house’s last renovation
# * zipcode - What zipcode area the house is in
# * lat - Lattitude
# * long - Longitude
# * sqft_living15 - The square footage of interior housing living space for the nearest 15 neighbors
# * sqft_lot15 - The square footage of the land lots of the nearest 15 neighbors
#
# #### The problem
# * Develop a neural network model to predict the house price based on the above features.

# %%
#
# Your code to import libraries, numpy, pandas, matplotlib,  seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Your code to read the data from the file provided.

df = pd.read_csv('kc_house_data.csv')
df.tail(10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21603         2270      5536     2.0           0     0  ...      8
# 21604         1490      1126     3.0           0     0  ...      8
# 21605         2520      6023     2.0           0     0  ...      9
# 21606         3510      7200     2.0           0     0  ...      9
# 21607         1310      1294     2.0           0     0  ...      8
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21603        2270              0      2003             0    98065  47.5389
# 21604        1490              0      2014             0    98144  47.5699
# 21605        2520              0      2014             0    98056  47.5137
# 21606        2600            910      2009             0    98136  47.5537
# 21607        1180            130      2008             0    98116  47.5773
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21603 -121.881           2270        5731
# 21604 -122.288           1400        1230
# 21605 -122.167           2520        6023
# 21606 -122.398           2050        6200
# 21607 -122.409           1330        1265
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [10 rows x 21 columns]

# %% [markdown]
# # Exploratory Data Analysis
#
# Perform some data analysis using the libraries above.
# Visualise the features to understand the problem and use the appropriate features for the model.

# %%
# Your code to check if any null value is present in the dataset. Hint - use isnull() in pandas
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
# Your code to describe the dataset to get imortant properties of it.

# %% [markdown]
# # Let's see how price columns look like i.e. how prices are distributed.

# %%
plt.figure(figsize=(12,8))
sns.distplot(df['price'])
# Out:
# /var/folders/pl/tqnpqw0d0lg1qyvvvs2sk2kr0000gn/T/ipykernel_4669/4209215003.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# #### Let's look at the columns - number of bedroom in more detail
# #### Write code to plot the numbers of bedrooms and the number of times they appear in the data.
# ####The x-axis contains the number of bedrroms and the y axis will portray the number of times the particular bedroom appears in the column.
#
# #### Hint - use sns.countplot.

# %%
# Your code to plot number of bedrooms and their counts
plt.figure(figsize=(12,8))
sns.distplot(df['bedrooms'])
# Out:
# /var/folders/pl/tqnpqw0d0lg1qyvvvs2sk2kr0000gn/T/ipykernel_4669/626863922.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedrooms'])
# <Axes: xlabel='bedrooms', ylabel='Density'>

# %% [markdown]
# # Plot a scatter plot between the price and sqft_living column.

# %%
# You code to visualize an scatter plot.
sns.scatterplot(x=df['price'], y=df['sqft_living'])
# Out:
# <Axes: xlabel='price', ylabel='sqft_living'>

# %%
sns.boxplot(x='bedrooms',y='price',data=df)
# Out:
# <Axes: xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# ### Geographical Properties
#
# Visulaize an scatter plot between price and longitude (long) and latidtude (lat)  columns.

# %%
# Your code to visualize an scatter plot between price and longitude (long) column.
sns.boxplot(x='lat',y='price',data=df)
# Out:
# <Axes: xlabel='lat', ylabel='price'>

# %%
# Your code to visualize an scatter plot between price and latitude(lat) column.
sns.boxplot(x='long',y='price',data=df)
# Out:
# <Axes: xlabel='long', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x = 'long', y = 'lat', data = df, hue = 'price')
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %% [markdown]
# # Sort the values in the dataframe according to price and print first few rows.

# %%
# Your code to sort data frame according to the price (ascending order) and see first few rows. 
# Hint - Use df.sort_values and combine it with head()
df = df.sort_values('price')
df.head()
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000  75000.0         1       0.00          670
# 15293    40000362  20140506T000000  78000.0         2       1.00          780
# 465    8658300340  20140523T000000  80000.0         1       0.75          430
# 16198  3028200080  20150324T000000  81000.0         2       1.00          730
# 8274   3883800011  20141105T000000  82000.0         3       1.00          860
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1149      43377     1.0           0     0  ...      3         670
# 15293     16344     1.0           0     0  ...      5         780
# 465        5050     1.0           0     0  ...      4         430
# 16198      9975     1.0           0     0  ...      5         730
# 8274      10426     1.0           0     0  ...      6         860
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1149               0      1966             0    98022  47.2638 -121.906
# 15293              0      1942             0    98168  47.4739 -122.280
# 465                0      1912             0    98014  47.6499 -121.909
# 16198              0      1943             0    98168  47.4808 -122.315
# 8274               0      1954             0    98146  47.4987 -122.341
#
#        sqft_living15  sqft_lot15
# 1149            1160       42882
# 15293           1700       10387
# 465             1200        7500
# 16198            860        9000
# 8274            1140       11250
#
# [5 rows x 21 columns]

# %% [markdown]
# #### The following code visualizes the price intensity with the latitude and longitude for 1% and 99% of the data separately.
#
# #### You need to add comment on each line of the code.

# %%
len(df)*(0.01)
# Out:
# 216.13

# %%
non_top_1_perc = df.sort_values('price',ascending=False).iloc[216:]
non_top_1_perc
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 3281   8964800025  20150226T000000  1965000.0         5       3.75
# 12577  2806300065  20150422T000000  1960000.0         4       4.00
# 12283  1923000260  20141015T000000  1959000.0         5       4.50
# 1152   4055701200  20150421T000000  1955000.0         4       2.75
# 9175   3124059023  20150213T000000  1955000.0         3       1.75
# ...           ...              ...        ...       ...        ...
# 8274   3883800011  20141105T000000    82000.0         3       1.00
# 16198  3028200080  20150324T000000    81000.0         2       1.00
# 465    8658300340  20140523T000000    80000.0         1       0.75
# 15293    40000362  20140506T000000    78000.0         2       1.00
# 1149   3421079032  20150217T000000    75000.0         1       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 3281          3940     13738     1.5           0     3  ...      9
# 12577         4430     31353     2.0           0     0  ...     12
# 12283         6200     23373     3.0           0     1  ...     11
# 1152          3120      7898     1.0           1     4  ...      8
# 9175          3330     12566     1.0           1     4  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 8274           860     10426     1.0           0     0  ...      6
# 16198          730      9975     1.0           0     0  ...      5
# 465            430      5050     1.0           0     0  ...      4
# 15293          780     16344     1.0           0     0  ...      5
# 1149           670     43377     1.0           0     0  ...      3
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 3281         3940              0      1951             0    98004  47.6203
# 12577        4430              0      1998             0    98005  47.6422
# 12283        5050           1150      1988             0    98040  47.5632
# 1152         1560           1560      1963             0    98034  47.7165
# 9175         1940           1390      1960             0    98040  47.5287
# ...           ...            ...       ...           ...      ...      ...
# 8274          860              0      1954             0    98146  47.4987
# 16198         730              0      1943             0    98168  47.4808
# 465           430              0      1912             0    98014  47.6499
# 15293         780              0      1942             0    98168  47.4739
# 1149          670              0      1966             0    98022  47.2638
#
#           long  sqft_living15  sqft_lot15
# 3281  -122.212           2370       13320
# 12577 -122.157           3900       35237
# 12283 -122.215           3700       14486
# 1152  -122.259           2630       13868
# 9175  -122.220           3730       16560
# ...        ...            ...         ...
# 8274  -122.341           1140       11250
# 16198 -122.315            860        9000
# 465   -121.909           1200        7500
# 15293 -122.280           1700       10387
# 1149  -121.906           1160       42882
#
# [21397 rows x 21 columns]

# %%
plt.figure(figsize=(12,8))

sns.scatterplot(x=df['long'],y=df['lat'])
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))

sns.scatterplot(x='long',y='lat', 
                data=non_top_1_perc,hue='price', 
                palette='RdYlGn',edgecolor=None,alpha=0.2)
# Out:
# <Axes: xlabel='long', ylabel='lat'>

# %% [markdown]
# ### Other Features
# # Let's have a box plot between waterfront and price.
#
# # Explain what box plot is doing?

# %%
sns.boxplot(x='waterfront',y='price',data=df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %% [markdown]
# ## Working with Feature Data

# %%
# Your code to print first few rows of the data.
df.head()
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000  75000.0         1       0.00          670
# 15293    40000362  20140506T000000  78000.0         2       1.00          780
# 465    8658300340  20140523T000000  80000.0         1       0.75          430
# 16198  3028200080  20150324T000000  81000.0         2       1.00          730
# 8274   3883800011  20141105T000000  82000.0         3       1.00          860
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1149      43377     1.0           0     0  ...      3         670
# 15293     16344     1.0           0     0  ...      5         780
# 465        5050     1.0           0     0  ...      4         430
# 16198      9975     1.0           0     0  ...      5         730
# 8274      10426     1.0           0     0  ...      6         860
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1149               0      1966             0    98022  47.2638 -121.906
# 15293              0      1942             0    98168  47.4739 -122.280
# 465                0      1912             0    98014  47.6499 -121.909
# 16198              0      1943             0    98168  47.4808 -122.315
# 8274               0      1954             0    98146  47.4987 -122.341
#
#        sqft_living15  sqft_lot15
# 1149            1160       42882
# 15293           1700       10387
# 465             1200        7500
# 16198            860        9000
# 8274            1140       11250
#
# [5 rows x 21 columns]

# %%
# Your code to print info about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21613 entries, 1149 to 7252
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.6+ MB

# %% [markdown]
# Following code is dropping the column ID.
#
# Question - why are dropping this column?

# %%
df = df.drop('id',axis=1)

# %% [markdown]
# ### Feature Engineering from Date
#
# Transform the features into useful formats to apply appropriate Deep NN technique!

# %%
df['date'] = pd.to_datetime(df['date'])
df['month'] = df['date'].apply(lambda date:date.month)
df['year'] = df['date'].apply(lambda date:date.year)
#df['year'] = df['date'].apply(lambda date:date.year)

# Your code to check what above code is doing.
df.head()
# Out:
#             date    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1149  2015-02-17  75000.0         1       0.00          670     43377     1.0
# 15293 2014-05-06  78000.0         2       1.00          780     16344     1.0
# 465   2014-05-23  80000.0         1       0.75          430      5050     1.0
# 16198 2015-03-24  81000.0         2       1.00          730      9975     1.0
# 8274  2014-11-05  82000.0         3       1.00          860     10426     1.0
#
#        waterfront  view  condition  ...  sqft_basement  yr_built  \
# 1149            0     0          3  ...              0      1966
# 15293           0     0          1  ...              0      1942
# 465             0     0          2  ...              0      1912
# 16198           0     0          1  ...              0      1943
# 8274            0     0          3  ...              0      1954
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 1149              0    98022  47.2638 -121.906           1160       42882
# 15293             0    98168  47.4739 -122.280           1700       10387
# 465               0    98014  47.6499 -121.909           1200        7500
# 16198             0    98168  47.4808 -122.315            860        9000
# 8274              0    98146  47.4987 -122.341           1140       11250
#
#        month  year
# 1149       2  2015
# 15293      5  2014
# 465        5  2014
# 16198      3  2015
# 8274      11  2014
#
# [5 rows x 22 columns]

# %%
sns.boxplot(x='year',y='price',data=df)
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %%
# Your code to visualize boxplot between month and price
sns.boxplot(x='month',y='price',data=df)
# Out:
# <Axes: xlabel='month', ylabel='price'>

# %%
# we do not need the 'date' column anymore

df = df.drop('date',axis=1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'month', 'year'],
#       dtype='object')

# %%
df['zipcode'].value_counts()
# Out:
# zipcode
# 98103    602
# 98038    590
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    105
# 98010    100
# 98024     81
# 98148     57
# 98039     50
# Name: count, Length: 70, dtype: int64

# %% [markdown]
# Should we remove zipcode?  If so, remove it.

# %%
# Your code to remove zip code - Hint - Use df.drop
# Your code to remove 'date' column.

# %%
df.head()
# Out:
#          price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1149   75000.0         1       0.00          670     43377     1.0
# 15293  78000.0         2       1.00          780     16344     1.0
# 465    80000.0         1       0.75          430      5050     1.0
# 16198  81000.0         2       1.00          730      9975     1.0
# 8274   82000.0         3       1.00          860     10426     1.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# 1149            0     0          3      3  ...              0      1966
# 15293           0     0          1      5  ...              0      1942
# 465             0     0          2      4  ...              0      1912
# 16198           0     0          1      5  ...              0      1943
# 8274            0     0          3      6  ...              0      1954
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 1149              0    98022  47.2638 -121.906           1160       42882
# 15293             0    98168  47.4739 -122.280           1700       10387
# 465               0    98014  47.6499 -121.909           1200        7500
# 16198             0    98168  47.4808 -122.315            860        9000
# 8274              0    98146  47.4987 -122.341           1140       11250
#
#        month  year
# 1149       2  2015
# 15293      5  2014
# 465        5  2014
# 16198      3  2015
# 8274      11  2014
#
# [5 rows x 21 columns]

# %%
# could make sense due to scaling, higher should correlate to more value
df['yr_renovated'].value_counts()
# Out:
# yr_renovated
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2000       35
#         ...
# 1944        1
# 1951        1
# 1948        1
# 1959        1
# 1954        1
# Name: count, Length: 70, dtype: int64

# %%
df['sqft_basement'].value_counts()
# Out:
# sqft_basement
# 0       13126
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 207         1
# 516         1
# 283         1
# 556         1
# 3480        1
# Name: count, Length: 306, dtype: int64

# %% [markdown]
# ## Scaling and Train Test Split
#
# Scikit-Learn is used to split out the train-test library.

# %% [markdown]
# First separate input and output. Input will be stored in the variable X and output in variable y.

# %%
# Your code to store all columns except price column in variable X. Hint - Use pd.drop()
X = df.drop('price',axis=1)
# Your code to store output (price column) in variable y
y = df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=42)

# %%
# Your code to separate X and y into X_train, X_test, y_train, y_test i.e. getting training and testing set for the model.

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# You can choose your unique test data size as a percentage of the original dataset. 
# It is better to consider the range from 15 to 35%
# Out:
# (15129, 20) (6484, 20) (15129,) (6484,)

# %% [markdown]
# ### Scaling
#
# Features are scaled to be in a proper range to be useful for modeling.
# Scaling converts all values between 0-1.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train= scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# fit_transform() is used on the training data so that we can scale the training data and also learn the scaling parameters of that data, such as the mean and variance of the features of the training set. These learned and fixed parameters are then used to scale our test data with the transform() function.

# %%
# Your code to print shapes of X_train, X_test, y_train, y_test and see if shapes are okay.
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (15129, 20) (6484, 20) (15129,) (6484,)

# %% [markdown]
# ## Creating a Model
#
# Build a Deep NN model with appropriate layers using Keras.

# %%
#
# Import Libraries for Neural Network model development.
#
from tensorflow.keras import Sequential, layers
from tensorflow.keras.layers import Dense

# %% [markdown]
# Develop your own Neural Network model with suitable number of input, output, and any number of hidden layers. Since we are predicting a value, the number of neurons in outpit layer should be one.

# %%
#
# Your code to build MLP neural network model.
#

model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(512,  activation='relu'),
    Dense(512,  activation='relu'),
    Dense(256,  activation='relu'),
  
    Dense(256, activation='relu' ),
    Dense(80, activation='relu' ),
    Dense(60, activation='relu' ),
    Dense(40, activation='relu' ),
    Dense(20, activation='relu'),
    Dense(1)
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               2688
#
#  dense_1 (Dense)             (None, 512)               66048
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dense_4 (Dense)             (None, 256)               65792
#
#  dense_5 (Dense)             (None, 80)                20560
#
#  dense_6 (Dense)             (None, 60)                4860
#
#  dense_7 (Dense)             (None, 40)                2440
#
#  dense_8 (Dense)             (None, 20)                820
#
#  dense_9 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 557213 (2.13 MB)
# Trainable params: 557213 (2.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Training the Model
#
# Write the code to train the neural network model. Use the following of your choice:
#
#
#
# 1.   Optimization method
# 2.   Batch size
# 3.   Number of epochs.
#
# Test for various optimizers and check which one performs better in terms of loss function = 'mse'.
#
# Use following APIs
# * https://keras.io/api/optimizers/
# * https://keras.io/api/losses/regression_losses/
# * https://scikit-learn.org/stable/modules/model_evaluation.html#regression-metrics
# * https://keras.io/api/models/model_training_apis/

# %%
# ! add your chosen optimiser !

model.compile(optimizer='adam', loss='mse')

# %%
#
# Your code to train the model.
#
history = model.fit(
    x=X_train,
    y=y_train,
    epochs=50,
    verbose=1,
    callbacks=None,
    validation_split=0.2,
    validation_data=None,
    shuffle=True,
    class_weight=None,
    sample_weight=None,
    initial_epoch=0,
    steps_per_epoch=None,
    validation_steps=None,
    validation_batch_size=None,
    validation_freq=1,
    max_queue_size=10,
    workers=1,
    use_multiprocessing=False,
)
# Out:
# Epoch 1/50
# 379/379 [==============================] - 1s 3ms/step - loss: 98518360064.0000 - val_loss: 54420344832.0000
# Epoch 2/50
# 379/379 [==============================] - 1s 3ms/step - loss: 35336372224.0000 - val_loss: 47222317056.0000
# Epoch 3/50
# 379/379 [==============================] - 1s 3ms/step - loss: 31561371648.0000 - val_loss: 48017571840.0000
# Epoch 4/50
# 379/379 [==============================] - 1s 3ms/step - loss: 29491730432.0000 - val_loss: 39025430528.0000
# Epoch 5/50
# 379/379 [==============================] - 1s 3ms/step - loss: 27291181056.0000 - val_loss: 38633107456.0000
# Epoch 6/50
# 379/379 [==============================] - 1s 3ms/step - loss: 26266279936.0000 - val_loss: 35928813568.0000
# Epoch 7/50
# 379/379 [==============================] - 1s 3ms/step - loss: 26177996800.0000 - val_loss: 31603275776.0000
# Epoch 8/50
# 379/379 [==============================] - 1s 3ms/step - loss: 25929951232.0000 - val_loss: 31585271808.0000
# Epoch 9/50
# 379/379 [==============================] - 1s 3ms/step - loss: 22863835136.0000 - val_loss: 31288950784.0000
# Epoch 10/50
# 379/379 [==============================] - 1s 3ms/step - loss: 21647343616.0000 - val_loss: 29085360128.0000
# Epoch 11/50
# 379/379 [==============================] - 1s 3ms/step - loss: 21111664640.0000 - val_loss: 30252126208.0000
# Epoch 12/50
# 379/379 [==============================] - 1s 3ms/step - loss: 21985232896.0000 - val_loss: 27686977536.0000
# Epoch 13/50
# 379/379 [==============================] - 1s 3ms/step - loss: 19903371264.0000 - val_loss: 26135945216.0000
# Epoch 14/50
# 379/379 [==============================] - 1s 3ms/step - loss: 19575799808.0000 - val_loss: 24293810176.0000
# Epoch 15/50
# 379/379 [==============================] - 1s 3ms/step - loss: 19020255232.0000 - val_loss: 31025057792.0000
# Epoch 16/50
# 379/379 [==============================] - 1s 3ms/step - loss: 18059159552.0000 - val_loss: 24537667584.0000
# Epoch 17/50
# 379/379 [==============================] - 1s 3ms/step - loss: 17247338496.0000 - val_loss: 23850586112.0000
# Epoch 18/50
# 379/379 [==============================] - 1s 3ms/step - loss: 17061358592.0000 - val_loss: 23074138112.0000
# Epoch 19/50
# 379/379 [==============================] - 1s 3ms/step - loss: 18026164224.0000 - val_loss: 26995949568.0000
# Epoch 20/50
# 379/379 [==============================] - 1s 3ms/step - loss: 16160387072.0000 - val_loss: 36246183936.0000
# Epoch 21/50
# 379/379 [==============================] - 1s 3ms/step - loss: 17487312896.0000 - val_loss: 23622764544.0000
# Epoch 22/50
# 379/379 [==============================] - 1s 3ms/step - loss: 16188872704.0000 - val_loss: 24052828160.0000
# Epoch 23/50
# 379/379 [==============================] - 1s 3ms/step - loss: 15623707648.0000 - val_loss: 29415430144.0000
# Epoch 24/50
# 379/379 [==============================] - 1s 3ms/step - loss: 15441150976.0000 - val_loss: 32487639040.0000
# Epoch 25/50
# 379/379 [==============================] - 1s 3ms/step - loss: 16084344832.0000 - val_loss: 24381710336.0000
# Epoch 26/50
# 379/379 [==============================] - 1s 3ms/step - loss: 14831679488.0000 - val_loss: 21816449024.0000
# Epoch 27/50
# 379/379 [==============================] - 1s 3ms/step - loss: 15882532864.0000 - val_loss: 25128404992.0000
# Epoch 28/50
# 379/379 [==============================] - 1s 3ms/step - loss: 14054628352.0000 - val_loss: 20548120576.0000
# Epoch 29/50
# 379/379 [==============================] - 1s 3ms/step - loss: 14150003712.0000 - val_loss: 19751043072.0000
# Epoch 30/50
# 379/379 [==============================] - 1s 3ms/step - loss: 15273658368.0000 - val_loss: 22040131584.0000
# Epoch 31/50
# 379/379 [==============================] - 1s 3ms/step - loss: 13495536640.0000 - val_loss: 21855135744.0000
# Epoch 32/50
# 379/379 [==============================] - 1s 3ms/step - loss: 13734171648.0000 - val_loss: 22112894976.0000
# Epoch 33/50
# 379/379 [==============================] - 1s 3ms/step - loss: 14072352768.0000 - val_loss: 22263998464.0000
# Epoch 34/50
# 379/379 [==============================] - 1s 3ms/step - loss: 13303966720.0000 - val_loss: 24871149568.0000
# Epoch 35/50
# 379/379 [==============================] - 1s 3ms/step - loss: 13631506432.0000 - val_loss: 20618541056.0000
# Epoch 36/50
# 379/379 [==============================] - 1s 3ms/step - loss: 13313256448.0000 - val_loss: 19028742144.0000
# Epoch 37/50
# 379/379 [==============================] - 1s 3ms/step - loss: 12997217280.0000 - val_loss: 30527492096.0000
# Epoch 38/50
# 379/379 [==============================] - 1s 3ms/step - loss: 14960972800.0000 - val_loss: 20943026176.0000
# Epoch 39/50
# 379/379 [==============================] - 1s 3ms/step - loss: 12145233920.0000 - val_loss: 20188133376.0000
# Epoch 40/50
# 379/379 [==============================] - 1s 3ms/step - loss: 13771965440.0000 - val_loss: 18806892544.0000
# Epoch 41/50
# 379/379 [==============================] - 1s 3ms/step - loss: 11953788928.0000 - val_loss: 18104735744.0000
# Epoch 42/50
# 379/379 [==============================] - 1s 3ms/step - loss: 12162435072.0000 - val_loss: 22254518272.0000
# Epoch 43/50
# 379/379 [==============================] - 1s 3ms/step - loss: 13474717696.0000 - val_loss: 20129050624.0000
# Epoch 44/50
# 379/379 [==============================] - 1s 3ms/step - loss: 12270222336.0000 - val_loss: 19489075200.0000
# Epoch 45/50
# 379/379 [==============================] - 1s 3ms/step - loss: 12065463296.0000 - val_loss: 30613180416.0000
# Epoch 46/50
# 379/379 [==============================] - 1s 3ms/step - loss: 11993440256.0000 - val_loss: 18249668608.0000
# Epoch 47/50
# 379/379 [==============================] - 1s 3ms/step - loss: 12577319936.0000 - val_loss: 22320199680.0000
# Epoch 48/50
# 379/379 [==============================] - 1s 3ms/step - loss: 12120510464.0000 - val_loss: 22169470976.0000
# Epoch 49/50
# 379/379 [==============================] - 1s 3ms/step - loss: 11731481600.0000 - val_loss: 21760634880.0000
# Epoch 50/50
# 379/379 [==============================] - 1s 3ms/step - loss: 10984225792.0000 - val_loss: 19648534528.0000

# %% [markdown]
# # Following code gets the history of losses at every epoch.

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %% [markdown]
# # Evaluation on Test Data
#
# https://scikit-learn.org/stable/modules/model_evaluation.html#regression-metrics
#
# Scikit-Learn has metrics to evaluate the performance.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

# %% [markdown]
# #### Next, we will test the performance of our model by predicting on test dataset X_test.

# %%
# Your code to print X_test and see how test data looks like.
X_test
# Out:
# array([[0.09090909, 0.125     , 0.04301887, ..., 0.00863458, 0.27272727,
#         1.        ],
#        [0.09090909, 0.3125    , 0.09886792, ..., 0.00185907, 0.09090909,
#         1.        ],
#        [0.12121212, 0.3125    , 0.09735849, ..., 0.01066866, 1.        ,
#         0.        ],
#        ...,
#        [0.12121212, 0.34375   , 0.13962264, ..., 0.01653874, 0.18181818,
#         1.        ],
#        [0.03030303, 0.125     , 0.02415094, ..., 0.00762736, 0.63636364,
#         0.        ],
#        [0.15151515, 0.53125   , 0.46943396, ..., 0.02823783, 0.72727273,
#         0.        ]])

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Following you will predict the output based on the input data X_test.
#
# Lonk to API - https://keras.io/api/models/model_training_apis/#predict-method

# %%
# Your code to make a predictions using (model.predict (<input_data>) method ). 
# Store the predictions in the variable predictions
y_pred = model.predict(X_test)
# Out:
# 203/203 [==============================] - 0s 822us/step

# %% [markdown]
# ## Following code will test the error in the predicted values.
# ## Error is the difference between the predictions you made and real values (y_test)

# %%
print (mean_absolute_error(y_test, y_pred ))
#print (np.sqrt(mean_squared_error())) # There is an error in this line. Fix the error.
print (explained_variance_score(y_test,y_pred))
# Out:
# 82532.14066596623
# 0.8719613359708033

# %% [markdown]
# The following code plots the predicted values in a scatter plot. We have also plotted the perfect predictions.

# %%
predictions = y_pred

# %%
# Our predictions
plt.scatter(y_test, y_pred)

# Perfect predictions
plt.plot(y_test, y_test, 'r')

# %% [markdown]
# In the following code, we have plotted the error i.e. the difference between the actual and predicted values.

# %%
errors = y_test.values.reshape(6484, 1) - predictions
sns.distplot(errors)
# Out:
# /var/folders/pl/tqnpqw0d0lg1qyvvvs2sk2kr0000gn/T/ipykernel_4669/822056149.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(errors)
# <Axes: ylabel='Density'>

# %% [markdown]
# ### Following code makes prediction on a brand new house. Comment each line of the code.
#
# Try predicting price for a new home.

# %%
single_house = df.drop('price',axis=1).iloc[0]

# %%
single_house = scaler.transform(single_house.values.reshape(-1, 20))
# Out:
# /Users/chaitanyapavan/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
single_house
# Out:
# array([[0.03030303, 0.        , 0.02867925, 0.03681006, 0.        ,
#         0.        , 0.        , 0.5       , 0.16666667, 0.04166667,
#         0.        , 0.57391304, 0.        , 0.10606061, 0.14380937,
#         0.50913621, 0.13095853, 0.07540387, 0.09090909, 1.        ]])

# %%
model.predict(single_house)
# Out:
# 1/1 [==============================] - 0s 10ms/step
# array([[205527.08]], dtype=float32)

# %%
df.iloc[0]
# Out:
# price            75000.0000
# bedrooms             1.0000
# bathrooms            0.0000
# sqft_living        670.0000
# sqft_lot         43377.0000
# floors               1.0000
# waterfront           0.0000
# view                 0.0000
# condition            3.0000
# grade                3.0000
# sqft_above         670.0000
# sqft_basement        0.0000
# yr_built          1966.0000
# yr_renovated         0.0000
# zipcode          98022.0000
# lat                 47.2638
# long              -121.9060
# sqft_living15     1160.0000
# sqft_lot15       42882.0000
# month                2.0000
# year              2015.0000
# Name: 1149, dtype: float64

# %%
# The prediction result:

err = int(model.predict(single_house)) - df['price'].iloc[0]

print( 'absolute prediction error = ', err, ' $')
print( 'relative prediction error = ', err / df['price'].iloc[0] *100 , ' %')
# Out:
# 1/1 [==============================] - 0s 11ms/step
# absolute prediction error =  130527.0  $
# relative prediction error =  174.036  %

# %% [markdown]
# # Lab Logbook requirement:
#
# # Please record the plot of the  model's  loss after every epoch and a summary in lab logbook. You can obtain the model summary using the model.summary() method. The API for obtaining the model summary is defined in the following link:
#
#
# # https://keras.io/api/models/model/#summary-method
#
#
# # Ensure that no code or other information is added to the logbook and that only required information is present.  Marks will not be awarded if anything else is found in the logbook or instructions are not clearly followed.

# %% [markdown]
# ## Try different optimisations like changing model architecture, activation functions, training parameters.
